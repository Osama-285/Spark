# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("KafkaSparkStreamingNotebook") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.3") \
    .getOrCreate()
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://f5838d8c3611:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>KafkaSparkStreamingNotebook</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql.functions import expr

# Read from Kafka
df_raw = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "broker:29094") \
    .option("subscribe", "flight") \
    .option("startingOffsets", "earliest") \
    .load()

# Convert binary key/value to strings
df = df_raw.selectExpr("CAST(key AS STRING)", "CAST(value AS STRING)")

# Parse JSON if your Kafka messages are JSON
df_parsed = df.selectExpr("CAST(value AS STRING) as json") \
    .selectExpr("from_json(json, 'id INT, amount DOUBLE, type STRING') as data") \
    .select("data.*")

# Simple aggregation
agg = df_parsed.groupBy("type").sum("amount")

# Output to console (for debugging)
query = agg.writeStream \
    .outputMode("complete") \
    .format("console") \
    .start()

query.awaitTermination()

# %%
import json
import time
from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col, expr, concat, lit
from pyspark.sql.types import StructType, StringType, DoubleType, LongType
from pyspark.sql import functions as F
from kafka import KafkaProducer

# ----------------------------
# Config
# ----------------------------
BOOTSTRAP = "broker:29094"
SKEWED_TOPIC = "skewedevents"
METRICS_TOPIC = "metrics"

# Choose mode manually: "baseline", "broadcast", "salting"
mode = "baseline"   # change to "broadcast" or "salting"
enable_aqe = True   # toggle AQE

# ----------------------------
# Spark Session
# ----------------------------
spark = SparkSession.builder \
    .appName("skew-demo-notebook") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.3") \
    .config("spark.sql.shuffle.partitions", "6") \
    .config("spark.streaming.kafka.maxRatePerPartition", "10000") \
    .getOrCreate()

print("✅ Spark with Kafka ready — version:", spark.version)


if enable_aqe:
    spark.conf.set("spark.sql.adaptive.enabled", "true")
    spark.conf.set("spark.sql.adaptive.coalescePartitions.enabled", "true")

# ----------------------------
# Input schema & Kafka source
# ----------------------------
schema = StructType() \
    .add("event_id", LongType()) \
    .add("key", StringType()) \
    .add("value", DoubleType()) \
    .add("ts", LongType())

kdf = spark.readStream.format("kafka") \
    .option("kafka.bootstrap.servers", BOOTSTRAP) \
    .option("subscribe", SKEWED_TOPIC) \
    .option("startingOffsets", "latest") \
    .load()

json_df = kdf.select(from_json(col("value").cast("string"), schema).alias("j")).select("j.*")

# Small lookup table
lookup = spark.createDataFrame([(f"key_{i}", f"meta_{i}") for i in range(1, 101)], ["key", "meta"])

# ----------------------------
# Strategy selection
# ----------------------------
if mode == "baseline":
    joined = json_df.join(lookup, on="key", how="left")

elif mode == "broadcast":
    joined = json_df.join(F.broadcast(lookup), on="key", how="left")

elif mode == "salting":
    SALT_N = 6
    salts = spark.range(0, SALT_N).selectExpr("id as salt")
    lookup_salted = lookup.crossJoin(salts) \
        .withColumn("salted_key", concat(col("key"), lit("_"), col("salt"))) \
        .select("salted_key", "meta")

    salted_stream = json_df.withColumn(
        "salt",
        expr(f"CASE WHEN key='key_1' THEN floor(rand()*{SALT_N}) ELSE 0 END")
    ).withColumn("salted_key", concat(col("key"), lit("_"), col("salt")))

    joined = salted_stream.join(
        lookup_salted,
        salted_stream.salted_key == lookup_salted.salted_key,
        how="left"
    ).drop("salted_key")

else:
    raise ValueError("Unknown mode")

# ----------------------------
# Metrics sender
# ----------------------------
def send_metrics_to_kafka(batch_df, batch_id):
    counts = batch_df.groupBy("key").count().orderBy(F.desc("count"))
    total = batch_df.count()
    top_k = counts.limit(5).collect()
    counts_map = {r["key"]: r["count"] for r in top_k}

    metric = {
        "batch_id": int(batch_id),
        "mode": mode,
        "total_records": int(total),
        "top_keys": counts_map
    }

    print(f"[Metrics] Batch {batch_id} → {metric}")  # print in notebook

    producer = KafkaProducer(
        bootstrap_servers=BOOTSTRAP,
        value_serializer=lambda v: json.dumps(v).encode("utf-8")
    )
    producer.send(METRICS_TOPIC, value=metric)
    producer.flush()
    producer.close()

# ----------------------------
# Write stream (not forever!)
# ----------------------------
query = joined.writeStream \
    .outputMode("append") \
    .foreachBatch(lambda df, bid: (df.show(5, truncate=False), send_metrics_to_kafka(df, bid))) \
    .option("checkpointLocation", f"/tmp/checkpoint_{mode}") \
    .start()

# Run only for 60 seconds in notebook, then stop
query.awaitTermination(60)
query.stop()
# Out:
# ✅ Spark with Kafka ready — version: 3.5.3
# +-------+--------+-------------------+-------------+--------+
# |key    |event_id|value              |ts           |meta    |
# +-------+--------+-------------------+-------------+--------+
# |key_100|613     |0.17440322425258803|1758525805607|meta_100|
# |key_100|1346    |0.8190799589921869 |1758525815856|meta_100|
# |key_100|3804    |0.6932500495580937 |1758525849641|meta_100|
# |key_100|118     |0.875371296886914  |1758525798477|meta_100|
# |key_100|3310    |0.9362093732115965 |1758525842616|meta_100|
# +-------+--------+-------------------+-------------+--------+
# only showing top 5 rows
#
# [Metrics] Batch 1 → {'batch_id': 1, 'mode': 'baseline', 'total_records': 4143, 'top_keys': {'key_1': 3721, 'key_33': 11, 'key_10': 10, 'key_68': 10, 'key_84': 9}}
# +-------+--------+-------------------+-------------+--------+
# |key    |event_id|value              |ts           |meta    |
# +-------+--------+-------------------+-------------+--------+
# |key_100|4171    |0.1818848138475896 |1758525854767|meta_100|
# |key_100|4875    |0.17106323489579567|1758525864457|meta_100|
# |key_100|4893    |0.392386108894041  |1758525864722|meta_100|
# |key_13 |4690    |0.7256142519625165 |1758525861971|meta_13 |
# |key_13 |4907    |0.8210861921955402 |1758525864924|meta_13 |
# +-------+--------+-------------------+-------------+--------+
# only showing top 5 rows
#
# [Metrics] Batch 2 → {'batch_id': 2, 'mode': 'baseline', 'total_records': 1070, 'top_keys': {'key_1': 948, 'key_46': 6, 'key_23': 4, 'key_61': 4, 'key_6': 3}}
# +-------+--------+-------------------+-------------+--------+
# |key    |event_id|value              |ts           |meta    |
# +-------+--------+-------------------+-------------+--------+
# |key_100|5278    |0.3073466970056298 |1758525870058|meta_100|
# |key_13 |5273    |0.35506524560873653|1758525870011|meta_13 |
# |key_25 |5418    |0.02904816297565871|1758525871942|meta_25 |
# |key_40 |5221    |0.820727138381036  |1758525869305|meta_40 |
# |key_41 |5337    |0.26758815656131174|1758525870880|meta_41 |
# +-------+--------+-------------------+-------------+--------+
# only showing top 5 rows
#
# [Metrics] Batch 3 → {'batch_id': 3, 'mode': 'baseline', 'total_records': 228, 'top_keys': {'key_1': 203, 'key_70': 2, 'key_67': 1, 'key_88': 1, 'key_100': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_45|5592    |0.9543177319225677 |1758525874422|meta_45|
# |key_78|5471    |0.8062821208170378 |1758525872709|meta_78|
# |key_63|5478    |0.39402164398165107|1758525872813|meta_63|
# |key_63|5585    |0.7329485616470667 |1758525874312|meta_63|
# |key_98|5586    |0.01106812887000741|1758525874327|meta_98|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 4 → {'batch_id': 4, 'mode': 'baseline', 'total_records': 192, 'top_keys': {'key_1': 169, 'key_55': 3, 'key_32': 2, 'key_63': 2, 'key_88': 2}}
# +------+--------+------------------+-------------+-------+
# |key   |event_id|value             |ts           |meta   |
# +------+--------+------------------+-------------+-------+
# |key_48|5742    |0.3327669076134492|1758525876630|meta_48|
# |key_72|5771    |0.2643531859275521|1758525877033|meta_72|
# |key_78|5649    |0.6585156713623704|1758525875272|meta_78|
# |key_78|5737    |0.5145923582500576|1758525876553|meta_78|
# |key_93|5641    |0.8588311024720224|1758525875152|meta_93|
# +------+--------+------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 5 → {'batch_id': 5, 'mode': 'baseline', 'total_records': 165, 'top_keys': {'key_1': 148, 'key_78': 2, 'key_24': 1, 'key_15': 1, 'key_34': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_43|5814    |0.34838716922122936|1758525877670|meta_43|
# |key_63|5832    |0.9597618229805808 |1758525877921|meta_63|
# |key_30|5833    |0.22514172760589912|1758525877936|meta_30|
# |key_89|5889    |0.35859985045271525|1758525878782|meta_89|
# |key_96|5849    |0.5738006360859789 |1758525878172|meta_96|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 6 → {'batch_id': 6, 'mode': 'baseline', 'total_records': 129, 'top_keys': {'key_1': 116, 'key_8': 2, 'key_10': 1, 'key_43': 1, 'key_74': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_45|5984    |0.6979682884054473 |1758525880202|meta_45|
# |key_51|5945    |0.19837264968897594|1758525879624|meta_51|
# |key_90|6034    |0.400757818797695  |1758525880885|meta_90|
# |key_42|6018    |0.5219707283199706 |1758525880667|meta_42|
# |key_85|6042    |0.9522257815790433 |1758525881003|meta_85|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 7 → {'batch_id': 7, 'mode': 'baseline', 'total_records': 147, 'top_keys': {'key_1': 129, 'key_12': 1, 'key_27': 1, 'key_2': 1, 'key_65': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_19|6129    |0.8316958801097794 |1758525882077|meta_19|
# |key_4 |6199    |0.14149536786817984|1758525883048|meta_4 |
# |key_51|6186    |0.9513973081529926 |1758525882857|meta_51|
# |key_72|6133    |0.8839419435530206 |1758525882135|meta_72|
# |key_90|6188    |0.645999289667345  |1758525882888|meta_90|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 8 → {'batch_id': 8, 'mode': 'baseline', 'total_records': 170, 'top_keys': {'key_1': 146, 'key_96': 2, 'key_23': 1, 'key_19': 1, 'key_34': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_67|6322    |0.4552168912633404 |1758525884850|meta_67|
# |key_89|6326    |0.8191221749181485 |1758525884913|meta_89|
# |key_52|6353    |0.9897293319647041 |1758525885298|meta_52|
# |key_55|6278    |0.07814704324769361|1758525884223|meta_55|
# |key_57|6263    |0.8766611944925223 |1758525883999|meta_57|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 9 → {'batch_id': 9, 'mode': 'baseline', 'total_records': 116, 'top_keys': {'key_1': 107, 'key_52': 1, 'key_28': 1, 'key_2': 1, 'key_81': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_60|6478    |0.7194499947403602 |1758525886983|meta_60|
# |key_77|6361    |0.9048170483913321 |1758525885397|meta_77|
# |key_88|6415    |0.13208053922023333|1758525886122|meta_88|
# |key_38|6463    |0.10160289780147858|1758525886798|meta_38|
# |key_20|6480    |0.8991324276614463 |1758525887014|meta_20|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 10 → {'batch_id': 10, 'mode': 'baseline', 'total_records': 184, 'top_keys': {'key_1': 171, 'key_38': 1, 'key_77': 1, 'key_60': 1, 'key_88': 1}}
# +------+--------+--------------------+-------------+-------+
# |key   |event_id|value               |ts           |meta   |
# +------+--------+--------------------+-------------+-------+
# |key_40|6563    |0.13792696258890835 |1758525888123|meta_40|
# |key_90|6624    |0.7250260256500489  |1758525889029|meta_90|
# |key_98|6637    |0.7390147474615996  |1758525889216|meta_98|
# |key_21|6656    |0.9032929299515359  |1758525889500|meta_21|
# |key_53|6593    |0.032034356116503404|1758525888577|meta_53|
# +------+--------+--------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 11 → {'batch_id': 11, 'mode': 'baseline', 'total_records': 114, 'top_keys': {'key_1': 102, 'key_26': 1, 'key_17': 1, 'key_86': 1, 'key_98': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_51|6734    |0.3770552863553496 |1758525890648|meta_51|
# |key_91|6669    |0.29422034013572185|1758525889718|meta_91|
# |key_53|6738    |0.7961747218383419 |1758525890711|meta_53|
# |key_38|6699    |0.45825566801880036|1758525890132|meta_38|
# |key_1 |6666    |0.7696996962335411 |1758525889671|meta_1 |
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 12 → {'batch_id': 12, 'mode': 'baseline', 'total_records': 90, 'top_keys': {'key_1': 85, 'key_38': 1, 'key_53': 1, 'key_51': 1, 'key_50': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_83|6772    |0.5125961570219407 |1758525891198|meta_83|
# |key_91|6851    |0.2656587741944795 |1758525892359|meta_91|
# |key_11|6789    |0.21994030828788458|1758525891450|meta_11|
# |key_21|6784    |0.4008939749644137 |1758525891374|meta_21|
# |key_53|6750    |0.7977870547313117 |1758525890879|meta_53|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 13 → {'batch_id': 13, 'mode': 'baseline', 'total_records': 104, 'top_keys': {'key_1': 95, 'key_26': 1, 'key_11': 1, 'key_83': 1, 'key_21': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_51|6909    |0.9157644799869659 |1758525893233|meta_51|
# |key_67|6941    |0.44389594687944856|1758525893689|meta_67|
# |key_7 |6897    |0.8016088428563038 |1758525893046|meta_7 |
# |key_30|6949    |0.7333370405632736 |1758525893811|meta_30|
# |key_64|6873    |0.8096107754298205 |1758525892690|meta_64|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 14 → {'batch_id': 14, 'mode': 'baseline', 'total_records': 102, 'top_keys': {'key_1': 88, 'key_3': 2, 'key_2': 1, 'key_67': 1, 'key_22': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_40|6980    |0.9956182406052604 |1758525894235|meta_40|
# |key_51|6967    |0.5747868602683238 |1758525894029|meta_51|
# |key_78|6988    |0.7829307248368783 |1758525894358|meta_78|
# |key_80|6966    |0.9530538208575181 |1758525894014|meta_80|
# |key_83|6976    |0.09459153442966195|1758525894171|meta_83|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 15 → {'batch_id': 15, 'mode': 'baseline', 'total_records': 81, 'top_keys': {'key_1': 67, 'key_43': 1, 'key_18': 1, 'key_67': 1, 'key_34': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_40|7062    |0.23795231482216872|1758525895399|meta_40|
# |key_93|7136    |0.6983327834691395 |1758525896436|meta_93|
# |key_71|7142    |0.6407324826057011 |1758525896517|meta_71|
# |key_6 |7042    |0.2573256103166932 |1758525895149|meta_6 |
# |key_61|7115    |0.2915668635445605 |1758525896124|meta_61|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 16 → {'batch_id': 16, 'mode': 'baseline', 'total_records': 121, 'top_keys': {'key_1': 113, 'key_8': 2, 'key_61': 1, 'key_40': 1, 'key_6': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_51|7200    |0.20543704253514972|1758525897358|meta_51|
# |key_51|7170    |0.34593488310435794|1758525896904|meta_51|
# |key_47|7234    |0.8246076067170431 |1758525897856|meta_47|
# |key_7 |7246    |0.8288911607519421 |1758525898030|meta_7 |
# |key_30|7242    |0.5720429118615001 |1758525897967|meta_30|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 17 → {'batch_id': 17, 'mode': 'baseline', 'total_records': 95, 'top_keys': {'key_1': 81, 'key_51': 2, 'key_47': 1, 'key_31': 1, 'key_7': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_45|7275    |0.46177234309718673|1758525898436|meta_45|
# |key_93|7334    |0.39130948054860215|1758525899207|meta_93|
# |key_14|7302    |0.4392222540247427 |1758525898824|meta_14|
# |key_71|7338    |0.2761084290819733 |1758525899269|meta_71|
# |key_6 |7316    |0.9321693982238813 |1758525898998|meta_6 |
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 18 → {'batch_id': 18, 'mode': 'baseline', 'total_records': 98, 'top_keys': {'key_1': 90, 'key_75': 1, 'key_6': 1, 'key_71': 1, 'key_45': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_13|7445    |0.06446998893307465|1758525900656|meta_13|
# |key_48|7371    |0.6984586046179523 |1758525899702|meta_48|
# |key_90|7355    |0.6982794000607624 |1758525899516|meta_90|
# |key_14|7381    |0.7954307513049724 |1758525899820|meta_14|
# |key_47|7437    |0.25308978784120206|1758525900537|meta_47|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 19 → {'batch_id': 19, 'mode': 'baseline', 'total_records': 117, 'top_keys': {'key_1': 104, 'key_67': 2, 'key_56': 1, 'key_86': 1, 'key_14': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_25|7560    |0.05134897811029315|1758525902161|meta_25|
# |key_72|7515    |0.19764925752978713|1758525901614|meta_72|
# |key_83|7545    |0.6788276018224136 |1758525901961|meta_83|
# |key_85|7481    |0.1464404082898939 |1758525901159|meta_85|
# |key_15|7468    |0.5775293837409833 |1758525900973|meta_15|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 20 → {'batch_id': 20, 'mode': 'baseline', 'total_records': 120, 'top_keys': {'key_1': 110, 'key_85': 1, 'key_34': 1, 'key_15': 1, 'key_35': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_13|7641    |0.38189563074689026|1758525903328|meta_13|
# |key_51|7610    |0.3764470426121188 |1758525902875|meta_51|
# |key_83|7623    |0.653452432209831  |1758525903061|meta_83|
# |key_93|7617    |0.8401187822825489 |1758525902975|meta_93|
# |key_10|7599    |0.5880070146260169 |1758525902725|meta_10|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 21 → {'batch_id': 21, 'mode': 'baseline', 'total_records': 98, 'top_keys': {'key_1': 91, 'key_13': 1, 'key_66': 1, 'key_10': 1, 'key_51': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_13|7764    |0.6370773004081433 |1758525905060|meta_13|
# |key_25|7765    |0.34894862984399333|1758525905062|meta_25|
# |key_5 |7686    |0.31201220441449073|1758525904016|meta_5 |
# |key_7 |7690    |0.6044625460082689 |1758525904077|meta_7 |
# |key_11|7705    |0.8636692848906706 |1758525904296|meta_11|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 22 → {'batch_id': 22, 'mode': 'baseline', 'total_records': 120, 'top_keys': {'key_1': 106, 'key_10': 2, 'key_11': 1, 'key_20': 1, 'key_66': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_40|7817    |0.39951157151303873|1758525905788|meta_40|
# |key_40|7816    |0.32346169632541333|1758525905772|meta_40|
# |key_18|7820    |0.5644064722116888 |1758525905835|meta_18|
# |key_2 |7830    |0.8929743677771856 |1758525905983|meta_2 |
# |key_1 |7807    |0.11431944096346203|1758525905635|meta_1 |
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 23 → {'batch_id': 23, 'mode': 'baseline', 'total_records': 85, 'top_keys': {'key_1': 79, 'key_40': 2, 'key_18': 1, 'key_32': 1, 'key_2': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_40|7952    |0.500403790582479  |1758525907729|meta_40|
# |key_51|7945    |0.8469658118200127 |1758525907621|meta_51|
# |key_68|7965    |0.8423518016618269 |1758525907921|meta_68|
# |key_43|7932    |0.5382872848760939 |1758525907421|meta_43|
# |key_67|7908    |0.19734984218122353|1758525907109|meta_67|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 24 → {'batch_id': 24, 'mode': 'baseline', 'total_records': 100, 'top_keys': {'key_1': 88, 'key_53': 1, 'key_35': 1, 'key_73': 1, 'key_8': 1}}
# +------+--------+------------------+-------------+-------+
# |key   |event_id|value             |ts           |meta   |
# +------+--------+------------------+-------------+-------+
# |key_41|8014    |0.9233555349943535|1758525908660|meta_41|
# |key_48|8039    |0.6305682582779949|1758525909023|meta_48|
# |key_5 |7998    |0.7653535283504749|1758525908421|meta_5 |
# |key_68|8079    |0.5239192211188677|1758525909561|meta_68|
# |key_91|8087    |0.3317554610630702|1758525909647|meta_91|
# +------+--------+------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 25 → {'batch_id': 25, 'mode': 'baseline', 'total_records': 103, 'top_keys': {'key_1': 88, 'key_16': 2, 'key_53': 1, 'key_23': 1, 'key_14': 1}}

# %%
import json
import time
from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json, col, expr, concat, lit
from pyspark.sql.types import StructType, StringType, DoubleType, LongType
from pyspark.sql import functions as F
from kafka import KafkaProducer

# ----------------------------
# Config
# ----------------------------
BOOTSTRAP = "broker:29094"
SKEWED_TOPIC = "skewedevents"
METRICS_TOPIC = "metrics"

# Choose mode manually: "baseline", "broadcast", "salting"
mode = "baseline"   # change to "broadcast" or "salting"
enable_aqe = True   # toggle AQE

# ----------------------------
# Spark Session
# ----------------------------
spark = SparkSession.builder \
    .appName("skew-demo-notebook") \
    .config("spark.jars.packages", "org.apache.spark:spark-sql-kafka-0-10_2.12:3.5.3") \
    .config("spark.sql.shuffle.partitions", "6") \
    .config("spark.streaming.kafka.maxRatePerPartition", "10000") \
    .getOrCreate()

print("✅ Spark with Kafka ready — version:", spark.version)


if enable_aqe:
    spark.conf.set("spark.sql.adaptive.enabled", "true")
    spark.conf.set("spark.sql.adaptive.coalescePartitions.enabled", "true")

# ----------------------------
# Input schema & Kafka source
# ----------------------------
schema = StructType() \
    .add("event_id", LongType()) \
    .add("key", StringType()) \
    .add("value", DoubleType()) \
    .add("ts", LongType())

kdf = spark.readStream.format("kafka") \
    .option("kafka.bootstrap.servers", BOOTSTRAP) \
    .option("subscribe", SKEWED_TOPIC) \
    .option("startingOffsets", "latest") \
    .load()

json_df = kdf.select(from_json(col("value").cast("string"), schema).alias("j")).select("j.*")

# Small lookup table
lookup = spark.createDataFrame([(f"key_{i}", f"meta_{i}") for i in range(1, 101)], ["key", "meta"])

# ----------------------------
# Strategy selection
# ----------------------------
if mode == "baseline":
    joined = json_df.join(lookup, on="key", how="left")

elif mode == "broadcast":
    joined = json_df.join(F.broadcast(lookup), on="key", how="left")

elif mode == "salting":
    SALT_N = 6
    salts = spark.range(0, SALT_N).selectExpr("id as salt")
    lookup_salted = lookup.crossJoin(salts) \
        .withColumn("salted_key", concat(col("key"), lit("_"), col("salt"))) \
        .select("salted_key", "meta")

    salted_stream = json_df.withColumn(
        "salt",
        expr(f"CASE WHEN key='key_1' THEN floor(rand()*{SALT_N}) ELSE 0 END")
    ).withColumn("salted_key", concat(col("key"), lit("_"), col("salt")))

    joined = salted_stream.join(
        lookup_salted,
        salted_stream.salted_key == lookup_salted.salted_key,
        how="left"
    ).drop("salted_key")

else:
    raise ValueError("Unknown mode")

# ----------------------------
# Metrics sender
# ----------------------------
def send_metrics_to_kafka(batch_df, batch_id):
    counts = batch_df.groupBy("key").count().orderBy(F.desc("count"))
    total = batch_df.count()
    top_k = counts.limit(5).collect()
    counts_map = {r["key"]: r["count"] for r in top_k}

    metric = {
        "batch_id": int(batch_id),
        "mode": mode,
        "total_records": int(total),
        "top_keys": counts_map
    }

    print(f"[Metrics] Batch {batch_id} → {metric}")  # print in notebook

    producer = KafkaProducer(
        bootstrap_servers=BOOTSTRAP,
        value_serializer=lambda v: json.dumps(v).encode("utf-8")
    )
    producer.send(METRICS_TOPIC, value=metric)
    producer.flush()
    producer.close()

# ----------------------------
# Write stream (not forever!)
# ----------------------------
query = joined.writeStream \
    .outputMode("append") \
    .foreachBatch(lambda df, bid: (df.show(5, truncate=False), send_metrics_to_kafka(df, bid))) \
    .option("checkpointLocation", f"/tmp/checkpoint_{mode}") \
    .start()

# Run only for 60 seconds in notebook, then stop
query.awaitTermination(60)
query.stop()
# Out:
# ✅ Spark with Kafka ready — version: 3.5.3
# +-------+--------+-------------------+-------------+--------+
# |key    |event_id|value              |ts           |meta    |
# +-------+--------+-------------------+-------------+--------+
# |key_100|613     |0.17440322425258803|1758525805607|meta_100|
# |key_100|1346    |0.8190799589921869 |1758525815856|meta_100|
# |key_100|3804    |0.6932500495580937 |1758525849641|meta_100|
# |key_100|118     |0.875371296886914  |1758525798477|meta_100|
# |key_100|3310    |0.9362093732115965 |1758525842616|meta_100|
# +-------+--------+-------------------+-------------+--------+
# only showing top 5 rows
#
# [Metrics] Batch 1 → {'batch_id': 1, 'mode': 'baseline', 'total_records': 4143, 'top_keys': {'key_1': 3721, 'key_33': 11, 'key_10': 10, 'key_68': 10, 'key_84': 9}}
# +-------+--------+-------------------+-------------+--------+
# |key    |event_id|value              |ts           |meta    |
# +-------+--------+-------------------+-------------+--------+
# |key_100|4171    |0.1818848138475896 |1758525854767|meta_100|
# |key_100|4875    |0.17106323489579567|1758525864457|meta_100|
# |key_100|4893    |0.392386108894041  |1758525864722|meta_100|
# |key_13 |4690    |0.7256142519625165 |1758525861971|meta_13 |
# |key_13 |4907    |0.8210861921955402 |1758525864924|meta_13 |
# +-------+--------+-------------------+-------------+--------+
# only showing top 5 rows
#
# [Metrics] Batch 2 → {'batch_id': 2, 'mode': 'baseline', 'total_records': 1070, 'top_keys': {'key_1': 948, 'key_46': 6, 'key_23': 4, 'key_61': 4, 'key_6': 3}}
# +-------+--------+-------------------+-------------+--------+
# |key    |event_id|value              |ts           |meta    |
# +-------+--------+-------------------+-------------+--------+
# |key_100|5278    |0.3073466970056298 |1758525870058|meta_100|
# |key_13 |5273    |0.35506524560873653|1758525870011|meta_13 |
# |key_25 |5418    |0.02904816297565871|1758525871942|meta_25 |
# |key_40 |5221    |0.820727138381036  |1758525869305|meta_40 |
# |key_41 |5337    |0.26758815656131174|1758525870880|meta_41 |
# +-------+--------+-------------------+-------------+--------+
# only showing top 5 rows
#
# [Metrics] Batch 3 → {'batch_id': 3, 'mode': 'baseline', 'total_records': 228, 'top_keys': {'key_1': 203, 'key_70': 2, 'key_67': 1, 'key_88': 1, 'key_100': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_45|5592    |0.9543177319225677 |1758525874422|meta_45|
# |key_78|5471    |0.8062821208170378 |1758525872709|meta_78|
# |key_63|5478    |0.39402164398165107|1758525872813|meta_63|
# |key_63|5585    |0.7329485616470667 |1758525874312|meta_63|
# |key_98|5586    |0.01106812887000741|1758525874327|meta_98|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 4 → {'batch_id': 4, 'mode': 'baseline', 'total_records': 192, 'top_keys': {'key_1': 169, 'key_55': 3, 'key_32': 2, 'key_63': 2, 'key_88': 2}}
# +------+--------+------------------+-------------+-------+
# |key   |event_id|value             |ts           |meta   |
# +------+--------+------------------+-------------+-------+
# |key_48|5742    |0.3327669076134492|1758525876630|meta_48|
# |key_72|5771    |0.2643531859275521|1758525877033|meta_72|
# |key_78|5649    |0.6585156713623704|1758525875272|meta_78|
# |key_78|5737    |0.5145923582500576|1758525876553|meta_78|
# |key_93|5641    |0.8588311024720224|1758525875152|meta_93|
# +------+--------+------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 5 → {'batch_id': 5, 'mode': 'baseline', 'total_records': 165, 'top_keys': {'key_1': 148, 'key_78': 2, 'key_24': 1, 'key_15': 1, 'key_34': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_43|5814    |0.34838716922122936|1758525877670|meta_43|
# |key_63|5832    |0.9597618229805808 |1758525877921|meta_63|
# |key_30|5833    |0.22514172760589912|1758525877936|meta_30|
# |key_89|5889    |0.35859985045271525|1758525878782|meta_89|
# |key_96|5849    |0.5738006360859789 |1758525878172|meta_96|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 6 → {'batch_id': 6, 'mode': 'baseline', 'total_records': 129, 'top_keys': {'key_1': 116, 'key_8': 2, 'key_10': 1, 'key_43': 1, 'key_74': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_45|5984    |0.6979682884054473 |1758525880202|meta_45|
# |key_51|5945    |0.19837264968897594|1758525879624|meta_51|
# |key_90|6034    |0.400757818797695  |1758525880885|meta_90|
# |key_42|6018    |0.5219707283199706 |1758525880667|meta_42|
# |key_85|6042    |0.9522257815790433 |1758525881003|meta_85|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 7 → {'batch_id': 7, 'mode': 'baseline', 'total_records': 147, 'top_keys': {'key_1': 129, 'key_12': 1, 'key_27': 1, 'key_2': 1, 'key_65': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_19|6129    |0.8316958801097794 |1758525882077|meta_19|
# |key_4 |6199    |0.14149536786817984|1758525883048|meta_4 |
# |key_51|6186    |0.9513973081529926 |1758525882857|meta_51|
# |key_72|6133    |0.8839419435530206 |1758525882135|meta_72|
# |key_90|6188    |0.645999289667345  |1758525882888|meta_90|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 8 → {'batch_id': 8, 'mode': 'baseline', 'total_records': 170, 'top_keys': {'key_1': 146, 'key_96': 2, 'key_23': 1, 'key_19': 1, 'key_34': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_67|6322    |0.4552168912633404 |1758525884850|meta_67|
# |key_89|6326    |0.8191221749181485 |1758525884913|meta_89|
# |key_52|6353    |0.9897293319647041 |1758525885298|meta_52|
# |key_55|6278    |0.07814704324769361|1758525884223|meta_55|
# |key_57|6263    |0.8766611944925223 |1758525883999|meta_57|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 9 → {'batch_id': 9, 'mode': 'baseline', 'total_records': 116, 'top_keys': {'key_1': 107, 'key_52': 1, 'key_28': 1, 'key_2': 1, 'key_81': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_60|6478    |0.7194499947403602 |1758525886983|meta_60|
# |key_77|6361    |0.9048170483913321 |1758525885397|meta_77|
# |key_88|6415    |0.13208053922023333|1758525886122|meta_88|
# |key_38|6463    |0.10160289780147858|1758525886798|meta_38|
# |key_20|6480    |0.8991324276614463 |1758525887014|meta_20|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 10 → {'batch_id': 10, 'mode': 'baseline', 'total_records': 184, 'top_keys': {'key_1': 171, 'key_38': 1, 'key_77': 1, 'key_60': 1, 'key_88': 1}}
# +------+--------+--------------------+-------------+-------+
# |key   |event_id|value               |ts           |meta   |
# +------+--------+--------------------+-------------+-------+
# |key_40|6563    |0.13792696258890835 |1758525888123|meta_40|
# |key_90|6624    |0.7250260256500489  |1758525889029|meta_90|
# |key_98|6637    |0.7390147474615996  |1758525889216|meta_98|
# |key_21|6656    |0.9032929299515359  |1758525889500|meta_21|
# |key_53|6593    |0.032034356116503404|1758525888577|meta_53|
# +------+--------+--------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 11 → {'batch_id': 11, 'mode': 'baseline', 'total_records': 114, 'top_keys': {'key_1': 102, 'key_26': 1, 'key_17': 1, 'key_86': 1, 'key_98': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_51|6734    |0.3770552863553496 |1758525890648|meta_51|
# |key_91|6669    |0.29422034013572185|1758525889718|meta_91|
# |key_53|6738    |0.7961747218383419 |1758525890711|meta_53|
# |key_38|6699    |0.45825566801880036|1758525890132|meta_38|
# |key_1 |6666    |0.7696996962335411 |1758525889671|meta_1 |
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 12 → {'batch_id': 12, 'mode': 'baseline', 'total_records': 90, 'top_keys': {'key_1': 85, 'key_38': 1, 'key_53': 1, 'key_51': 1, 'key_50': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_83|6772    |0.5125961570219407 |1758525891198|meta_83|
# |key_91|6851    |0.2656587741944795 |1758525892359|meta_91|
# |key_11|6789    |0.21994030828788458|1758525891450|meta_11|
# |key_21|6784    |0.4008939749644137 |1758525891374|meta_21|
# |key_53|6750    |0.7977870547313117 |1758525890879|meta_53|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 13 → {'batch_id': 13, 'mode': 'baseline', 'total_records': 104, 'top_keys': {'key_1': 95, 'key_26': 1, 'key_11': 1, 'key_83': 1, 'key_21': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_51|6909    |0.9157644799869659 |1758525893233|meta_51|
# |key_67|6941    |0.44389594687944856|1758525893689|meta_67|
# |key_7 |6897    |0.8016088428563038 |1758525893046|meta_7 |
# |key_30|6949    |0.7333370405632736 |1758525893811|meta_30|
# |key_64|6873    |0.8096107754298205 |1758525892690|meta_64|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 14 → {'batch_id': 14, 'mode': 'baseline', 'total_records': 102, 'top_keys': {'key_1': 88, 'key_3': 2, 'key_2': 1, 'key_67': 1, 'key_22': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_40|6980    |0.9956182406052604 |1758525894235|meta_40|
# |key_51|6967    |0.5747868602683238 |1758525894029|meta_51|
# |key_78|6988    |0.7829307248368783 |1758525894358|meta_78|
# |key_80|6966    |0.9530538208575181 |1758525894014|meta_80|
# |key_83|6976    |0.09459153442966195|1758525894171|meta_83|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 15 → {'batch_id': 15, 'mode': 'baseline', 'total_records': 81, 'top_keys': {'key_1': 67, 'key_43': 1, 'key_18': 1, 'key_67': 1, 'key_34': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_40|7062    |0.23795231482216872|1758525895399|meta_40|
# |key_93|7136    |0.6983327834691395 |1758525896436|meta_93|
# |key_71|7142    |0.6407324826057011 |1758525896517|meta_71|
# |key_6 |7042    |0.2573256103166932 |1758525895149|meta_6 |
# |key_61|7115    |0.2915668635445605 |1758525896124|meta_61|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 16 → {'batch_id': 16, 'mode': 'baseline', 'total_records': 121, 'top_keys': {'key_1': 113, 'key_8': 2, 'key_61': 1, 'key_40': 1, 'key_6': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_51|7200    |0.20543704253514972|1758525897358|meta_51|
# |key_51|7170    |0.34593488310435794|1758525896904|meta_51|
# |key_47|7234    |0.8246076067170431 |1758525897856|meta_47|
# |key_7 |7246    |0.8288911607519421 |1758525898030|meta_7 |
# |key_30|7242    |0.5720429118615001 |1758525897967|meta_30|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 17 → {'batch_id': 17, 'mode': 'baseline', 'total_records': 95, 'top_keys': {'key_1': 81, 'key_51': 2, 'key_47': 1, 'key_31': 1, 'key_7': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_45|7275    |0.46177234309718673|1758525898436|meta_45|
# |key_93|7334    |0.39130948054860215|1758525899207|meta_93|
# |key_14|7302    |0.4392222540247427 |1758525898824|meta_14|
# |key_71|7338    |0.2761084290819733 |1758525899269|meta_71|
# |key_6 |7316    |0.9321693982238813 |1758525898998|meta_6 |
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 18 → {'batch_id': 18, 'mode': 'baseline', 'total_records': 98, 'top_keys': {'key_1': 90, 'key_75': 1, 'key_6': 1, 'key_71': 1, 'key_45': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_13|7445    |0.06446998893307465|1758525900656|meta_13|
# |key_48|7371    |0.6984586046179523 |1758525899702|meta_48|
# |key_90|7355    |0.6982794000607624 |1758525899516|meta_90|
# |key_14|7381    |0.7954307513049724 |1758525899820|meta_14|
# |key_47|7437    |0.25308978784120206|1758525900537|meta_47|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 19 → {'batch_id': 19, 'mode': 'baseline', 'total_records': 117, 'top_keys': {'key_1': 104, 'key_67': 2, 'key_56': 1, 'key_86': 1, 'key_14': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_25|7560    |0.05134897811029315|1758525902161|meta_25|
# |key_72|7515    |0.19764925752978713|1758525901614|meta_72|
# |key_83|7545    |0.6788276018224136 |1758525901961|meta_83|
# |key_85|7481    |0.1464404082898939 |1758525901159|meta_85|
# |key_15|7468    |0.5775293837409833 |1758525900973|meta_15|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 20 → {'batch_id': 20, 'mode': 'baseline', 'total_records': 120, 'top_keys': {'key_1': 110, 'key_85': 1, 'key_34': 1, 'key_15': 1, 'key_35': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_13|7641    |0.38189563074689026|1758525903328|meta_13|
# |key_51|7610    |0.3764470426121188 |1758525902875|meta_51|
# |key_83|7623    |0.653452432209831  |1758525903061|meta_83|
# |key_93|7617    |0.8401187822825489 |1758525902975|meta_93|
# |key_10|7599    |0.5880070146260169 |1758525902725|meta_10|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 21 → {'batch_id': 21, 'mode': 'baseline', 'total_records': 98, 'top_keys': {'key_1': 91, 'key_13': 1, 'key_66': 1, 'key_10': 1, 'key_51': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_13|7764    |0.6370773004081433 |1758525905060|meta_13|
# |key_25|7765    |0.34894862984399333|1758525905062|meta_25|
# |key_5 |7686    |0.31201220441449073|1758525904016|meta_5 |
# |key_7 |7690    |0.6044625460082689 |1758525904077|meta_7 |
# |key_11|7705    |0.8636692848906706 |1758525904296|meta_11|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 22 → {'batch_id': 22, 'mode': 'baseline', 'total_records': 120, 'top_keys': {'key_1': 106, 'key_10': 2, 'key_11': 1, 'key_20': 1, 'key_66': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_40|7817    |0.39951157151303873|1758525905788|meta_40|
# |key_40|7816    |0.32346169632541333|1758525905772|meta_40|
# |key_18|7820    |0.5644064722116888 |1758525905835|meta_18|
# |key_2 |7830    |0.8929743677771856 |1758525905983|meta_2 |
# |key_1 |7807    |0.11431944096346203|1758525905635|meta_1 |
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 23 → {'batch_id': 23, 'mode': 'baseline', 'total_records': 85, 'top_keys': {'key_1': 79, 'key_40': 2, 'key_18': 1, 'key_32': 1, 'key_2': 1}}
# +------+--------+-------------------+-------------+-------+
# |key   |event_id|value              |ts           |meta   |
# +------+--------+-------------------+-------------+-------+
# |key_40|7952    |0.500403790582479  |1758525907729|meta_40|
# |key_51|7945    |0.8469658118200127 |1758525907621|meta_51|
# |key_68|7965    |0.8423518016618269 |1758525907921|meta_68|
# |key_43|7932    |0.5382872848760939 |1758525907421|meta_43|
# |key_67|7908    |0.19734984218122353|1758525907109|meta_67|
# +------+--------+-------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 24 → {'batch_id': 24, 'mode': 'baseline', 'total_records': 100, 'top_keys': {'key_1': 88, 'key_53': 1, 'key_35': 1, 'key_73': 1, 'key_8': 1}}
# +------+--------+------------------+-------------+-------+
# |key   |event_id|value             |ts           |meta   |
# +------+--------+------------------+-------------+-------+
# |key_41|8014    |0.9233555349943535|1758525908660|meta_41|
# |key_48|8039    |0.6305682582779949|1758525909023|meta_48|
# |key_5 |7998    |0.7653535283504749|1758525908421|meta_5 |
# |key_68|8079    |0.5239192211188677|1758525909561|meta_68|
# |key_91|8087    |0.3317554610630702|1758525909647|meta_91|
# +------+--------+------------------+-------------+-------+
# only showing top 5 rows
#
# [Metrics] Batch 25 → {'batch_id': 25, 'mode': 'baseline', 'total_records': 103, 'top_keys': {'key_1': 88, 'key_16': 2, 'key_53': 1, 'key_23': 1, 'key_14': 1}}

# %%
# Out:
# Spark Version: 3.5.3
