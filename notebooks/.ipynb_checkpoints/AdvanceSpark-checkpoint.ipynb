# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("AdvancedSpark").getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://25980bb9571e:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>AdvancedSpark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sc = spark.sparkContext

# %%
from pyspark import AccumulatorParam

class MultiCounterAccumulator(AccumulatorParam):
    def zero(self, initialValue):
        return {"null_arrival": 0, "weekend_flights": 0}

    def addInPlace(self, v1,v2):
        v1["null_arrival"] += v2["null_arrival"]
        v1["weekend_flights"] += v2["weekend_flights"]
        return v1

multi_counter = sc.accumulator(
    {"null_arrival":0, "weekend_flights": 0},
    MultiCounterAccumulator()
)

df = spark.read.csv("Flight_Schedule.csv", header = True, inferSchema = True)

rdd = df.rdd

def update_counters(row):
    counts = {"null_arrival": 0, "weekend_flights": 0}
    # Check for null arrival time
    if row["scheduledArrivalTime"] is None:
        counts["null_arrival"] += 1
    # Check if the flight operates on a weekend day
    days = row["dayOfWeek"].split(",") if row["dayOfWeek"] else []
    if "Saturday" in days or "Sunday" in days:
        counts["weekend_flights"] += 1
    return counts

rdd.foreach(lambda row: multi_counter.add(update_counters(row)))
results = multi_counter.value
print(f"Null Arrival Times: {results['null_arrival']}")
print(f"Weekend Flights: {results['weekend_flights']}")
# Out:
# Null Arrival Times: 10774
# Weekend Flights: 28354

# %%
import logging
from pyspark import AccumulatorParam

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("flight_schedule_analysis.log"),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

class MultiCounterAccumulator(AccumulatorParam):
    def zero(self, initialValue):
        logger.info("Setting initial accumulator value")
        return {"null_arrival": 0, "weekend_flights": 0}
    
    def addInPlace(self, v1, v2):
        logger.debug(f"Adding accumulator values: {v1} + {v2}")
        v1["null_arrival"] += v2["null_arrival"]
        v1["weekend_flights"] += v2["weekend_flights"]
        return v1

# Create an accumulator
logger.info("Creating accumulator with initial values")
multi_counter = sc.accumulator(
    {"null_arrival": 0, "weekend_flights": 0},
    MultiCounterAccumulator()
)
logger.info("Accumulator created successfully")

# Load the dataset
logger.info("Flight_Schedule.csv")
df = spark.read.csv("Flight_Schedule.csv", header=True, inferSchema=True)
logger.info("Dataset loaded successfully")

# Convert to RDD for lower-level control
logger.info("Converting DataFrame to RDD")
rdd = df.rdd
logger.info("DataFrame converted to RDD successfully")

# Function to update accumulator for each row
def update_counters(row):
    counts = {"null_arrival": 0, "weekend_flights": 0}
    logger.debug(f"Processing row: {row}")
    
    # Check for null arrival time
    if row["scheduledArrivalTime"] is None:
        counts["null_arrival"] += 1
        logger.debug(f"Found null scheduledArrivalTime in row: {row}")
    else:
        logger.debug(f"scheduledArrivalTime is not null in row: {row}")
    
    # Check if the flight operates on a weekend day
    days = row["dayOfWeek"].split(",") if row["dayOfWeek"] else []
    if "Saturday" in days or "Sunday" in days:
        counts["weekend_flights"] += 1
        logger.debug(f"Found weekend flight (Saturday/Sunday) in row: {row}")
    else:
        logger.debug(f"No weekend flight in row: {row}")
    
    return counts

# Process RDD and update accumulator
logger.info("Processing RDD and updating accumulator")
rdd.foreach(lambda row: multi_counter.add(update_counters(row)))
logger.info("RDD processing completed")

# Print results
results = multi_counter.value
logger.info(f"Final accumulator results: {results}")
print(f"Null Arrival Times: {results['null_arrival']}")
print(f"Weekend Flights: {results['weekend_flights']}")

# Stop Spark session
logger.info("Stopping Spark session")
# spark.stop()
logger.info("Spark session stopped successfully")
# Out:
# 2025-04-19 12:02:47,559 - INFO - Creating accumulator with initial values
# 2025-04-19 12:02:47,567 - INFO - Accumulator created successfully
# 2025-04-19 12:02:47,581 - INFO - Flight_Schedule.csv
# 2025-04-19 12:02:48,551 - INFO - Dataset loaded successfully
# 2025-04-19 12:02:48,553 - INFO - Converting DataFrame to RDD
# 2025-04-19 12:02:48,651 - INFO - DataFrame converted to RDD successfully
# 2025-04-19 12:02:48,654 - INFO - Processing RDD and updating accumulator
# 2025-04-19 12:02:48,665 - INFO - Setting initial accumulator value
# 2025-04-19 12:02:50,672 - INFO - RDD processing completed
# 2025-04-19 12:02:50,674 - INFO - Final accumulator results: {'null_arrival': 10774, 'weekend_flights': 28354}
# 2025-04-19 12:02:50,677 - INFO - Stopping Spark session
# 2025-04-19 12:02:50,680 - INFO - Spark session stopped successfully
# Null Arrival Times: 10774
# Weekend Flights: 28354

# %%
logging.basicConfig(
    level = logging.INFO,
    format = '%(asctime)s - %(levelname)s - %(message)s',
    handlers = [
        logging.FileHandler("simple_accumulator.log"),
        logging.StreamHandler()
    ]
)

logger = logging.getLogger(__name__)

logger.info("Initializing Spark session")
logger.info("Spark session initialized successfully")

logger.info("Creating accumulator for null arrival times")
null_arrival_counter = sc.accumulator(0)
logger.info("Accumulator created with initial value: 0")
logger.info("Flight_Schedule.csv")
df = spark.read.csv("Flight_Schedule.csv", header=True, inferSchema=True)
logger.info("Dataset loaded successfully")

logger.info("Converting DataFrame to RDD")
rdd = df.rdd
logger.info("DataFrame converted to RDD to successfully")

def check_null_arrival(row):
    if row["scheduledArrivalTime"] is None:
        logger.debug(f"Found null scheduledArrivalTime in row: {row}")
        null_arrival_counter.add(1)
    else:
        logger.debug(f"scheduledArrivalTime is not null in row: {row}")

logger.info("Processing RDD to count null arrival times")
rdd.foreach(check_null_arrival)
logger.info("RDD processing completed")

logger.info(f"Total null arrival times: {null_arrival_counter.value}")
print(f"Total Null Arrival Times: {null_arrival_counter.value}")

logger.info("Stopping Spark session")
# Out:
# 2025-04-19 13:07:15,679 - INFO - Initializing Spark session
# 2025-04-19 13:07:15,682 - INFO - Spark session initialized successfully
# 2025-04-19 13:07:15,683 - INFO - Creating accumulator for null arrival times
# 2025-04-19 13:07:15,685 - INFO - Accumulator created with initial value: 0
# 2025-04-19 13:07:15,686 - INFO - Flight_Schedule.csv
# 2025-04-19 13:07:16,408 - INFO - Dataset loaded successfully
# 2025-04-19 13:07:16,410 - INFO - Converting DataFrame to RDD
# 2025-04-19 13:07:16,470 - INFO - DataFrame converted to RDD to successfully
# 2025-04-19 13:07:16,472 - INFO - Processing RDD to count null arrival times
# 2025-04-19 13:07:17,428 - INFO - RDD processing completed
# 2025-04-19 13:07:17,430 - INFO - Total null arrival times: 10774
# 2025-04-19 13:07:17,432 - INFO - Stopping Spark session
# Total Null Arrival Times: 10774

# %%
import logging

logging.basicConfig(
    level=logging.DEBUG,  # Changed from INFO to DEBUG
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("simple_accumulator.log"),
        logging.StreamHandler()
    ]
)

logger = logging.getLogger(__name__)

logger.info("Creating accumulator for null arrival times")
null_arrival_counter = sc.accumulator(0)
logger.info("Accumulator created with initial value: 0")
logger.info("Flight_Schedule.csv")
df = spark.read.csv("Flight_Schedule.csv", header=True, inferSchema=True)
logger.info("Dataset loaded successfully")

logger.info("Converting DataFrame to RDD")
rdd = df.rdd
logger.info("DataFrame converted to RDD successfully")  # Fixed typo

# Function to check for null arrival times
def check_null_arrival(row):
    if row["scheduledArrivalTime"] is None:
        logger.debug(f"Found null scheduledArrivalTime in row: {row}")
        null_arrival_counter.add(1)
    else:
        logger.debug(f"scheduledArrivalTime is not null in row: {row}")

# Process RDD
logger.info("Processing RDD to count null arrival times")
rdd.foreach(check_null_arrival)
logger.info("RDD processing completed")

# Print result
logger.info(f"Total null arrival times: {null_arrival_counter.value}")
print(f"Total Null Arrival Times: {null_arrival_counter.value}")

# Stop Spark session
logger.info("Stopping Spark session")
# Out:
# 2025-04-19 13:16:29,438 - INFO - Creating accumulator for null arrival times
# 2025-04-19 13:16:29,440 - INFO - Accumulator created with initial value: 0
# 2025-04-19 13:16:29,442 - INFO - Flight_Schedule.csv
# 2025-04-19 13:16:30,010 - INFO - Dataset loaded successfully
# 2025-04-19 13:16:30,012 - INFO - Converting DataFrame to RDD
# 2025-04-19 13:16:30,103 - INFO - DataFrame converted to RDD successfully
# 2025-04-19 13:16:30,105 - INFO - Processing RDD to count null arrival times
# 2025-04-19 13:16:30,922 - INFO - RDD processing completed
# 2025-04-19 13:16:30,923 - INFO - Total null arrival times: 10774
# 2025-04-19 13:16:30,924 - INFO - Stopping Spark session
# Total Null Arrival Times: 10774

# %%
import logging
# from pyspark.sql import SparkSession

# Configure logging with DEBUG level
logging.basicConfig(
    level=logging.DEBUG,  # Changed from INFO to DEBUG
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("simple_accumulator.log"),
        logging.StreamHandler()
    ]
)

logger = logging.getLogger(__name__)

# Initialize Spark session
# logger.info("Initializing Spark session")
# spark = SparkSession.builder.appName("SimpleAccumulator").getOrCreate()
# sc = spark.sparkContext
# logger.info("Spark session initialized successfully")

# Create a simple accumulator
logger.info("Creating accumulator for null arrival times")
null_arrival_counter = sc.accumulator(0)
logger.info("Accumulator created with initial value: 0")

# Load the dataset
logger.info("Loading dataset from /opt/notebooks/Flight_Schedule.csv")
df = spark.read.csv("Flight_Schedule.csv", header=True, inferSchema=True)
logger.info("Dataset loaded successfully")

# Convert to RDD
logger.info("Converting DataFrame to RDD")
rdd = df.rdd
logger.info("DataFrame converted to RDD successfully")  # Fixed typo

# Function to check for null arrival times
def check_null_arrival(row):
    if row["scheduledArrivalTime"] is None:
        logger.debug(f"Found null scheduledArrivalTime in row: {row}")
        null_arrival_counter.add(1)
    else:
        logger.debug(f"scheduledArrivalTime is not null in row: {row}")

# Process RDD
logger.info("Processing RDD to count null arrival times")
rdd.foreach(check_null_arrival)
logger.info("RDD processing completed")

# Print result
logger.info(f"Total null arrival times: {null_arrival_counter.value}")
print(f"Total Null Arrival Times: {null_arrival_counter.value}")

# Stop Spark session
logger.info("Stopping Spark session")
spark.stop()
logger.info("Spark session stopped successfully")
# Out:
# 2025-04-19 13:18:42,720 - INFO - Creating accumulator for null arrival times
# 2025-04-19 13:18:42,722 - INFO - Accumulator created with initial value: 0
# 2025-04-19 13:18:42,724 - INFO - Loading dataset from /opt/notebooks/Flight_Schedule.csv
# 2025-04-19 13:18:43,173 - INFO - Dataset loaded successfully
# 2025-04-19 13:18:43,174 - INFO - Converting DataFrame to RDD
# 2025-04-19 13:18:43,202 - INFO - DataFrame converted to RDD successfully
# 2025-04-19 13:18:43,204 - INFO - Processing RDD to count null arrival times
# 2025-04-19 13:18:43,996 - INFO - RDD processing completed
# 2025-04-19 13:18:43,998 - INFO - Total null arrival times: 10774
# 2025-04-19 13:18:43,999 - INFO - Stopping Spark session
# Total Null Arrival Times: 10774
# 2025-04-19 13:18:45,003 - INFO - Spark session stopped successfully

# %%
import logging
from pyspark.sql import SparkSession
from pyspark import AccumulatorParam

# Configure logging
logging.basicConfig(
    level=logging.INFO,  # We can keep this at INFO since we'll log debug info differently
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler("simple_accumulator.log"),
        logging.StreamHandler()
    ]
)

logger = logging.getLogger(__name__)

# Initialize Spark session
logger.info("Initializing Spark session")
spark = SparkSession.builder.appName("SimpleAccumulator").getOrCreate()
sc = spark.sparkContext
logger.info("Spark session initialized successfully")

# Create a simple accumulator for counting null arrival times
logger.info("Creating accumulator for null arrival times")
null_arrival_counter = sc.accumulator(0)
logger.info("Accumulator created with initial value: 0")

# Create a custom accumulator to collect debug information
class ListAccumulator(AccumulatorParam):
    def zero(self, initialValue):
        return []
    
    def addInPlace(self, v1, v2):
        v1.extend(v2)
        return v1

# Create an accumulator to collect debug messages
logger.info("Creating accumulator for debug messages")
debug_messages = sc.accumulator([], ListAccumulator())
logger.info("Debug messages accumulator created successfully")

# Load the dataset
logger.info("Loading dataset from /opt/notebooks/Flight_Schedule.csv")
df = spark.read.csv("/opt/notebooks/Flight_Schedule.csv", header=True, inferSchema=True)
logger.info("Dataset loaded successfully")

# Convert to RDD
logger.info("Converting DataFrame to RDD")
rdd = df.rdd
logger.info("DataFrame converted to RDD successfully")

# Function to check for null arrival times and collect debug info
def check_null_arrival(row):
    if row["scheduledArrivalTime"] is None:
        debug_messages.add([f"Found null scheduledArrivalTime in row: {row}"])
        null_arrival_counter.add(1)
    else:
        debug_messages.add([f"scheduledArrivalTime is not null in row: {row}"])

# Process RDD
logger.info("Processing RDD to count null arrival times and collect debug info")
rdd.foreach(check_null_arrival)
logger.info("RDD processing completed")

# Log the collected debug messages
logger.info("Logging collected debug messages")
for msg in debug_messages.value:
    logger.info(msg)

# Print result
logger.info(f"Total null arrival times: {null_arrival_counter.value}")
print(f"Total Null Arrival Times: {null_arrival_counter.value}")

# Stop Spark session
logger.info("Stopping Spark session")
spark.stop()
logger.info("Spark session stopped successfully")
# Out:
# 2025-04-19 13:23:03,803 - INFO - Initializing Spark session
# 2025-04-19 13:23:03,965 - INFO - Spark session initialized successfully
# 2025-04-19 13:23:03,966 - INFO - Creating accumulator for null arrival times
# 2025-04-19 13:23:03,967 - INFO - Accumulator created with initial value: 0
# 2025-04-19 13:23:03,969 - INFO - Creating accumulator for debug messages
# 2025-04-19 13:23:03,970 - INFO - Debug messages accumulator created successfully
# 2025-04-19 13:23:03,972 - INFO - Loading dataset from /opt/notebooks/Flight_Schedule.csv
# 2025-04-19 13:23:04,492 - INFO - Dataset loaded successfully
# 2025-04-19 13:23:04,493 - INFO - Converting DataFrame to RDD
# 2025-04-19 13:23:04,544 - INFO - DataFrame converted to RDD successfully
# 2025-04-19 13:23:04,546 - INFO - Processing RDD to count null arrival times and collect debug info
# 2025-04-19 13:23:06,392 - INFO - RDD processing completed
# 2025-04-19 13:23:06,394 - INFO - Logging collected debug messages
# 2025-04-19 13:23:06,395 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='425', airline='GoAir', origin='Delhi', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 5, 45), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,398 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='423', airline='GoAir', origin='Delhi', destination='Hyderabad', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 30), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='28-10-2018')
# 2025-04-19 13:23:06,400 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='423', airline='GoAir', origin='Delhi', destination='Hyderabad', dayOfWeek='Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 30), scheduledArrivalTime=None, validFrom='03-11-2018', validTo='01-12-2018')
# 2025-04-19 13:23:06,402 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='423', airline='GoAir', origin='Delhi', destination='Hyderabad', dayOfWeek='Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 30), scheduledArrivalTime=None, validFrom='02-02-2019', validTo='30-03-2019')
# 2025-04-19 13:23:06,404 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='423', airline='GoAir', origin='Delhi', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 30), scheduledArrivalTime=None, validFrom='29-10-2018', validTo='30-11-2018')
# 2025-04-19 13:23:06,406 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='423', airline='GoAir', origin='Delhi', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 30), scheduledArrivalTime=None, validFrom='01-02-2019', validTo='29-03-2019')
# 2025-04-19 13:23:06,408 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='423', airline='GoAir', origin='Delhi', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 30), scheduledArrivalTime=None, validFrom='02-12-2018', validTo='31-01-2019')
# 2025-04-19 13:23:06,410 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='422', airline='GoAir', origin='Delhi', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 55), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,412 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='559', airline='GoAir', origin='Lucknow', destination='Hyderabad', dayOfWeek='Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 15, 45), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 17, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,414 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='580', airline='GoAir', origin='Kochi', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 4, 45), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 6, 15), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,416 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='587', airline='GoAir', origin='Kochi', destination='Hyderabad', dayOfWeek='Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 20), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 19, 20), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,419 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='587', airline='GoAir', origin='Kochi', destination='Hyderabad', dayOfWeek='Monday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 50), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 19, 20), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,420 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='553', airline='GoAir', origin='Ahmedabad', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 5), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 12, 45), validFrom='29-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,422 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='552', airline='GoAir', origin='Ahmedabad', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 35), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 22, 20), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,423 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='553', airline='GoAir', origin='Ahmedabad', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 0), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 12, 45), validFrom='01-04-2019', validTo='26-10-2019')
# 2025-04-19 13:23:06,426 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='552', airline='GoAir', origin='Ahmedabad', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 40), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 22, 20), validFrom='31-03-2019', validTo='26-10-2019')
# 2025-04-19 13:23:06,428 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='701', airline='GoAir', origin='Jaipur', destination='Hyderabad', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 8, 55), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 10, 55), validFrom='28-10-2018', validTo='24-03-2019')
# 2025-04-19 13:23:06,429 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='431', airline='GoAir', origin='Jaipur', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 12, 45), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 15, 5), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,432 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='385', airline='GoAir', origin='Jaipur', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 55), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,434 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='894', airline='GoAir', origin='Bengaluru', destination='Hyderabad', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 30), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 12, 40), validFrom='28-10-2018', validTo='24-03-2019')
# 2025-04-19 13:23:06,437 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='294', airline='GoAir', origin='Bengaluru', destination='Hyderabad', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 18, 55), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='24-03-2019')
# 2025-04-19 13:23:06,439 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='294', airline='GoAir', origin='Bengaluru', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 18, 55), scheduledArrivalTime=None, validFrom='29-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,442 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='894', airline='GoAir', origin='Bengaluru', destination='Hyderabad', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 40), scheduledArrivalTime=None, validFrom='31-03-2019', validTo='20-10-2019')
# 2025-04-19 13:23:06,443 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='952', airline='GoAir', origin='Guwahati', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 25), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 9, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,447 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='373', airline='GoAir', origin='Goa', destination='Hyderabad', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 4, 45), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='24-03-2019')
# 2025-04-19 13:23:06,448 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='662', airline='GoAir', origin='Goa', destination='Hyderabad', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 10, 45), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 12, 10), validFrom='28-10-2018', validTo='24-03-2019')
# 2025-04-19 13:23:06,450 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='370', airline='GoAir', origin='Goa', destination='Hyderabad', dayOfWeek='Monday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 19, 45), scheduledArrivalTime=None, validFrom='30-10-2018', validTo='26-03-2019')
# 2025-04-19 13:23:06,452 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='370', airline='GoAir', origin='Goa', destination='Hyderabad', dayOfWeek='Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 19, 45), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,454 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='572', airline='GoAir', origin='Goa', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 21, 55), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,455 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='121', airline='GoAir', origin='Kolkata', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 6, 35), scheduledArrivalTime=None, validFrom='29-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,458 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='121', airline='GoAir', origin='Kolkata', destination='Hyderabad', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 6, 35), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='28-10-2018')
# 2025-04-19 13:23:06,460 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='125', airline='GoAir', origin='Kolkata', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 10), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 19, 20), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,462 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='421', airline='GoAir', origin='Hyderabad', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 5, 35), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='29-03-2019')
# 2025-04-19 13:23:06,464 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='421', airline='GoAir', origin='Hyderabad', destination='Delhi', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 5, 45), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='28-10-2018')
# 2025-04-19 13:23:06,466 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='424', airline='GoAir', origin='Hyderabad', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 10, 20), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 12, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,468 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='996', airline='GoAir', origin='Hyderabad', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 22, 55), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 1, 25), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,469 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='616', airline='GoAir', origin='Nagpur', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 8, 25), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 10, 5), validFrom='01-12-2018', validTo='31-01-2019')
# 2025-04-19 13:23:06,471 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='618', airline='GoAir', origin='Nagpur', destination='Delhi', dayOfWeek='Monday,Tuesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 5), scheduledArrivalTime=None, validFrom='01-12-2018', validTo='31-01-2019')
# 2025-04-19 13:23:06,473 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='158', airline='GoAir', origin='Bagdogra', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 13, 40), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 16, 10), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,476 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='151', airline='GoAir', origin='Bagdogra', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 5), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 19, 25), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,477 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='851', airline='GoAir', origin='Bagdogra', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 15, 25), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 17, 40), validFrom='31-03-2019', validTo='26-10-2019')
# 2025-04-19 13:23:06,479 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='758', airline='GoAir', origin='Bagdogra', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 16, 20), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 18, 35), validFrom='31-03-2019', validTo='26-10-2019')
# 2025-04-19 13:23:06,481 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='208', airline='GoAir', origin='Lucknow', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 6, 40), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 8, 0), validFrom='28-10-2018', validTo='30-11-2018')
# 2025-04-19 13:23:06,482 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='208', airline='GoAir', origin='Lucknow', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 6, 40), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 8, 0), validFrom='01-02-2019', validTo='29-03-2019')
# 2025-04-19 13:23:06,484 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='212', airline='GoAir', origin='Lucknow', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 10, 45), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,485 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='188', airline='GoAir', origin='Lucknow', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 18, 30), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 20, 0), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,487 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='346', airline='GoAir', origin='Mumbai', destination='Delhi', dayOfWeek='Sunday,Tuesday,Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 1, 0), scheduledArrivalTime=None, validFrom='29-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,488 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='329', airline='GoAir', origin='Mumbai', destination='Delhi', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 6, 5), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='28-10-2018')
# 2025-04-19 13:23:06,490 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='329', airline='GoAir', origin='Mumbai', destination='Delhi', dayOfWeek='Sunday,Monday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 6, 5), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='29-03-2019')
# 2025-04-19 13:23:06,493 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='327', airline='GoAir', origin='Mumbai', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 55), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 10, 10), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,495 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='319', airline='GoAir', origin='Mumbai', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 9, 55), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,497 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='465', airline='GoAir', origin='Mumbai', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 12, 10), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='28-02-2019')
# 2025-04-19 13:23:06,501 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='465', airline='GoAir', origin='Mumbai', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 12, 10), scheduledArrivalTime=None, validFrom='01-03-2019', validTo='30-03-2019')
# 2025-04-19 13:23:06,503 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='439', airline='GoAir', origin='Mumbai', destination='Delhi', dayOfWeek='Monday,Thursday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 18, 30), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='29-03-2019')
# 2025-04-19 13:23:06,505 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='439', airline='GoAir', origin='Mumbai', destination='Delhi', dayOfWeek='Sunday,Tuesday,Wednesday,Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 18, 30), scheduledArrivalTime=None, validFrom='29-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,506 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='341', airline='GoAir', origin='Mumbai', destination='Delhi', dayOfWeek='Sunday,Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 15), scheduledArrivalTime=None, validFrom='29-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,509 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='643', airline='GoAir', origin='Mumbai', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 21, 15), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 23, 30), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,512 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='345', airline='GoAir', origin='Mumbai', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 22, 45), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,513 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='712', airline='GoAir', origin='Leh', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 9, 25), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 11, 5), validFrom='28-10-2018', validTo='31-01-2019')
# 2025-04-19 13:23:06,515 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='205', airline='GoAir', origin='Leh', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 25), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='31-01-2019')
# 2025-04-19 13:23:06,516 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='221', airline='GoAir', origin='Leh', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 25), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 12, 55), validFrom='01-02-2019', validTo='30-03-2019')
# 2025-04-19 13:23:06,518 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='134', airline='GoAir', origin='Patna', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 8, 15), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 10, 5), validFrom='28-10-2018', validTo='30-11-2018')
# 2025-04-19 13:23:06,519 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='134', airline='GoAir', origin='Patna', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 8, 15), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 10, 5), validFrom='01-02-2019', validTo='30-03-2019')
# 2025-04-19 13:23:06,521 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='944', airline='GoAir', origin='Patna', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 12, 55), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 14, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,522 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='132', airline='GoAir', origin='Patna', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 16, 5), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 17, 55), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,524 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='150', airline='GoAir', origin='Patna', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 10), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 18, 55), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,527 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='218', airline='GoAir', origin='Patna', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 5), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 21, 55), validFrom='28-10-2018', validTo='30-11-2018')
# 2025-04-19 13:23:06,528 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='218', airline='GoAir', origin='Patna', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 5), scheduledArrivalTime=None, validFrom='01-02-2019', validTo='30-03-2019')
# 2025-04-19 13:23:06,530 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='144', airline='GoAir', origin='Patna', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 22, 25), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 0, 20), validFrom='28-10-2018', validTo='30-11-2018')
# 2025-04-19 13:23:06,532 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='144', airline='GoAir', origin='Patna', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 22, 25), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 0, 20), validFrom='01-02-2019', validTo='30-03-2019')
# 2025-04-19 13:23:06,534 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='720', airline='GoAir', origin='Ahmedabad', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 8, 10), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 9, 50), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,536 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='718', airline='GoAir', origin='Ahmedabad', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 35), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 19, 15), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,537 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='714', airline='GoAir', origin='Ahmedabad', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 22, 20), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 0, 10), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,539 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='720', airline='GoAir', origin='Ahmedabad', destination='Delhi', dayOfWeek='Monday,Wednesday,Thursday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 9, 30), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 11, 20), validFrom='31-03-2019', validTo='25-10-2019')
# 2025-04-19 13:23:06,540 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='720', airline='GoAir', origin='Ahmedabad', destination='Delhi', dayOfWeek='Sunday,Tuesday,Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 9, 30), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 11, 20), validFrom='01-04-2019', validTo='26-10-2019')
# 2025-04-19 13:23:06,543 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='718', airline='GoAir', origin='Ahmedabad', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 18, 55), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 20, 40), validFrom='31-03-2019', validTo='26-10-2019')
# 2025-04-19 13:23:06,544 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='714', airline='GoAir', origin='Ahmedabad', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 22, 20), scheduledArrivalTime=None, validFrom='31-03-2019', validTo='26-10-2019')
# 2025-04-19 13:23:06,550 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='116', airline='GoAir', origin='Bengaluru', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 45), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 10, 40), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,560 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='124', airline='GoAir', origin='Bengaluru', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 40), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 14, 35), validFrom='29-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,572 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='118', airline='GoAir', origin='Bengaluru', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 55), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 23, 50), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,575 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='116', airline='GoAir', origin='Bengaluru', destination='Delhi', dayOfWeek='Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 45), scheduledArrivalTime=None, validFrom='06-04-2019', validTo='26-10-2019')
# 2025-04-19 13:23:06,577 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='116', airline='GoAir', origin='Bengaluru', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 45), scheduledArrivalTime=None, validFrom='01-04-2019', validTo='25-10-2019')
# 2025-04-19 13:23:06,578 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='120', airline='GoAir', origin='Bengaluru', destination='Delhi', dayOfWeek='Monday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 35), scheduledArrivalTime=None, validFrom='02-04-2019', validTo='22-10-2019')
# 2025-04-19 13:23:06,580 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='120', airline='GoAir', origin='Bengaluru', destination='Delhi', dayOfWeek='Sunday,Tuesday,Wednesday,Thursday,Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 40), scheduledArrivalTime=None, validFrom='01-04-2019', validTo='26-10-2019')
# 2025-04-19 13:23:06,581 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='246', airline='GoAir', origin='Ranchi', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 10), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 13, 10), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,585 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='138', airline='GoAir', origin='Ranchi', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 15, 15), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,588 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='148', airline='GoAir', origin='Ranchi', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 50), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,591 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='144', airline='GoAir', origin='Ranchi', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 22, 15), scheduledArrivalTime=None, validFrom='01-12-2018', validTo='31-01-2019')
# 2025-04-19 13:23:06,592 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='176', airline='GoAir', origin='Pune', destination='Delhi', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 1, 20), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='28-10-2018')
# 2025-04-19 13:23:06,593 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='176', airline='GoAir', origin='Pune', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 1, 20), scheduledArrivalTime=None, validFrom='29-10-2018', validTo='01-02-2019')
# 2025-04-19 13:23:06,595 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='176', airline='GoAir', origin='Pune', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 1, 20), scheduledArrivalTime=None, validFrom='02-02-2019', validTo='30-03-2019')
# 2025-04-19 13:23:06,596 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='174', airline='GoAir', origin='Pune', destination='Delhi', dayOfWeek='Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 10, 45), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 13, 10), validFrom='03-11-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,597 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='174', airline='GoAir', origin='Pune', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 15), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 13, 30), validFrom='28-10-2018', validTo='29-03-2019')
# 2025-04-19 13:23:06,599 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='278', airline='GoAir', origin='Pune', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 55), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 23, 15), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,600 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='155', airline='GoAir', origin='Guwahati', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 20), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 20, 15), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,602 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='205', airline='GoAir', origin='Jammu', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 10), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 12, 55), validFrom='01-02-2019', validTo='30-03-2019')
# 2025-04-19 13:23:06,605 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='186', airline='GoAir', origin='Jammu', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 16, 0), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 17, 25), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,607 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='285', airline='GoAir', origin='Goa', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 45), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 20, 15), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,609 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='128', airline='GoAir', origin='Kolkata', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 6, 0), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,610 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='102', airline='GoAir', origin='Kolkata', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 14, 20), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 16, 55), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,611 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='106', airline='GoAir', origin='Kolkata', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 23, 45), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,613 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='129', airline='GoAir', origin='Srinagar', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 9, 25), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 11, 10), validFrom='01-02-2019', validTo='30-03-2019')
# 2025-04-19 13:23:06,614 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='129', airline='GoAir', origin='Srinagar', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 15), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 12, 50), validFrom='28-10-2018', validTo='31-01-2019')
# 2025-04-19 13:23:06,616 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='224', airline='GoAir', origin='Srinagar', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 15, 40), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 16, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,617 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='697', airline='GoAir', origin='Srinagar', destination='Delhi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 16, 15), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 17, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,619 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='1315', airline='GoAir', origin='Ahmedabad', destination='Varanasi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 15, 20), scheduledArrivalTime=None, validFrom='01-05-2019', validTo='26-10-2019')
# 2025-04-19 13:23:06,620 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='710', airline='GoAir', origin='Ahmedabad', destination='Varanasi', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 16, 30), scheduledArrivalTime=None, validFrom='01-05-2019', validTo='26-10-2019')
# 2025-04-19 13:23:06,622 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='244', airline='GoAir', origin='Mumbai', destination='Bhubaneswar', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 0), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-11-2018')
# 2025-04-19 13:23:06,623 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='244', airline='GoAir', origin='Mumbai', destination='Bhubaneswar', dayOfWeek='Tuesday,Wednesday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 0), scheduledArrivalTime=None, validFrom='05-12-2018', validTo='31-01-2019')
# 2025-04-19 13:23:06,625 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='244', airline='GoAir', origin='Mumbai', destination='Bhubaneswar', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 0), scheduledArrivalTime=None, validFrom='01-02-2019', validTo='30-03-2019')
# 2025-04-19 13:23:06,627 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='736', airline='GoAir', origin='Patna', destination='Bhubaneswar', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 18, 55), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 20, 10), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,628 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='309', airline='GoAir', origin='Chennai', destination='Bhubaneswar', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 4, 50), scheduledArrivalTime=None, validFrom='29-10-2018', validTo='31-03-2019')
# 2025-04-19 13:23:06,630 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='411', airline='GoAir', origin='Kolkata', destination='Bhubaneswar', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 4, 25), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='28-10-2018')
# 2025-04-19 13:23:06,631 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='411', airline='GoAir', origin='Kolkata', destination='Bhubaneswar', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 4, 25), scheduledArrivalTime=None, validFrom='29-10-2018', validTo='01-12-2018')
# 2025-04-19 13:23:06,632 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='411', airline='GoAir', origin='Kolkata', destination='Bhubaneswar', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 4, 25), scheduledArrivalTime=None, validFrom='02-02-2019', validTo='30-03-2019')
# 2025-04-19 13:23:06,634 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='760', airline='GoAir', origin='Kolkata', destination='Bhubaneswar', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 9, 40), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 10, 55), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,636 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='405', airline='GoAir', origin='Kolkata', destination='Bhubaneswar', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 21, 50), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 23, 5), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,637 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='615', airline='GoAir', origin='Delhi', destination='Nagpur', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 6, 5), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 7, 55), validFrom='01-12-2018', validTo='31-01-2019')
# 2025-04-19 13:23:06,639 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='617', airline='GoAir', origin='Delhi', destination='Nagpur', dayOfWeek='Monday,Wednesday,Thursday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 55), scheduledArrivalTime=None, validFrom='02-12-2018', validTo='31-01-2019')
# 2025-04-19 13:23:06,641 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='617', airline='GoAir', origin='Delhi', destination='Nagpur', dayOfWeek='Sunday,Tuesday,Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 55), scheduledArrivalTime=None, validFrom='01-12-2018', validTo='30-01-2019')
# 2025-04-19 13:23:06,643 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='142', airline='GoAir', origin='Mumbai', destination='Nagpur', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 19, 0), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 20, 40), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,644 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='516', airline='GoAir', origin='Patna', destination='Nagpur', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 25), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='24-03-2019')
# 2025-04-19 13:23:06,645 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='473', airline='GoAir', origin='Patna', destination='Nagpur', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 22, 35), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 23, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,647 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='809', airline='GoAir', origin='Bengaluru', destination='Nagpur', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 10), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 12, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,649 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='812', airline='GoAir', origin='Bengaluru', destination='Nagpur', dayOfWeek='Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 22, 10), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 23, 55), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,650 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='812', airline='GoAir', origin='Bengaluru', destination='Nagpur', dayOfWeek='Monday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 23, 0), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 0, 45), validFrom='30-10-2018', validTo='26-03-2019')
# 2025-04-19 13:23:06,652 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='283', airline='GoAir', origin='Pune', destination='Nagpur', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 40), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 8, 55), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:06,654 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='831', airline='GoAir', origin='Goa', destination='Nagpur', dayOfWeek='Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 4, 40), scheduledArrivalTime=None, validFrom='03-11-2018', validTo='30-03-2019')
# ...
# 2025-04-19 13:23:12,919 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='946', airline='Vistara', origin='Delhi', destination='Guwahati', dayOfWeek='Tuesday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 20), scheduledArrivalTime=None, validFrom='31-10-2018', validTo='14-11-2018')
# 2025-04-19 13:23:12,920 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='946', airline='Vistara', origin='Delhi', destination='Guwahati', dayOfWeek='Tuesday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 20), scheduledArrivalTime=None, validFrom='21-11-2018', validTo='26-12-2018')
# 2025-04-19 13:23:12,921 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='946', airline='Vistara', origin='Delhi', destination='Guwahati', dayOfWeek='Tuesday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 20), scheduledArrivalTime=None, validFrom='02-01-2019', validTo='27-03-2019')
# 2025-04-19 13:23:12,923 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='946', airline='Vistara', origin='Delhi', destination='Guwahati', dayOfWeek='Sunday,Monday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 20), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 13, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,924 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='787', airline='Vistara', origin='Delhi', destination='Guwahati', dayOfWeek='Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 16, 0), scheduledArrivalTime=None, validFrom='15-12-2018', validTo='26-01-2019')
# 2025-04-19 13:23:12,925 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='787', airline='Vistara', origin='Delhi', destination='Guwahati', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 16, 0), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 18, 15), validFrom='10-12-2018', validTo='31-01-2019')
# 2025-04-19 13:23:12,926 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='725', airline='Vistara', origin='Bagdogra', destination='Guwahati', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 13, 50), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 14, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,927 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='833', airline='Vistara', origin='Delhi', destination='Chennai', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 30), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='28-10-2018')
# 2025-04-19 13:23:12,928 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='833', airline='Vistara', origin='Delhi', destination='Chennai', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 30), scheduledArrivalTime=None, validFrom='29-10-2018', validTo='10-12-2018')
# 2025-04-19 13:23:12,930 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='833', airline='Vistara', origin='Delhi', destination='Chennai', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 30), scheduledArrivalTime=None, validFrom='11-12-2018', validTo='01-02-2019')
# 2025-04-19 13:23:12,931 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='833', airline='Vistara', origin='Delhi', destination='Chennai', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 30), scheduledArrivalTime=None, validFrom='02-02-2019', validTo='30-03-2019')
# 2025-04-19 13:23:12,932 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='835', airline='Vistara', origin='Delhi', destination='Chennai', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 19, 55), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 22, 40), validFrom='28-10-2018', validTo='09-12-2018')
# 2025-04-19 13:23:12,933 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='835', airline='Vistara', origin='Delhi', destination='Chennai', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 19, 55), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 22, 40), validFrom='01-02-2019', validTo='30-03-2019')
# 2025-04-19 13:23:12,934 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='835', airline='Vistara', origin='Delhi', destination='Chennai', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 10), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 22, 45), validFrom='10-12-2018', validTo='31-01-2019')
# 2025-04-19 13:23:12,935 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='731', airline='Vistara', origin='Kochi', destination='Chennai', dayOfWeek='Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 15, 30), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 16, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,936 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='834', airline='Vistara', origin='Port Blair', destination='Chennai', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 14, 10), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 16, 30), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,937 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='734', airline='Vistara', origin='Kolkata', destination='Chennai', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 10, 45), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 13, 5), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,938 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='732', airline='Vistara', origin='Kolkata', destination='Chennai', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 30), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,940 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='611', airline='Vistara', origin='Srinagar', destination='Jammu', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 12, 40), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 13, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,941 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='725', airline='Vistara', origin='Bagdogra', destination='Dibrugarh', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 10, 35), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 11, 50), validFrom='31-03-2019', validTo='26-10-2019')
# 2025-04-19 13:23:12,943 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='855', airline='Vistara', origin='Delhi', destination='Goa', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 15), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 9, 50), validFrom='28-10-2018', validTo='24-03-2019')
# 2025-04-19 13:23:12,944 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='855', airline='Vistara', origin='Delhi', destination='Goa', dayOfWeek='Friday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 9, 0), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 11, 40), validFrom='03-11-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,945 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='847', airline='Vistara', origin='Delhi', destination='Goa', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 11, 10), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 13, 55), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,946 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='867', airline='Vistara', origin='Delhi', destination='Goa', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 40), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 21, 30), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,947 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='861', airline='Vistara', origin='Mumbai', destination='Goa', dayOfWeek='Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 6, 30), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 7, 50), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,948 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='747', airline='Vistara', origin='Delhi', destination='Kolkata', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 45), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 9, 55), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,950 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='707', airline='Vistara', origin='Delhi', destination='Kolkata', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 30), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 19, 35), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,951 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='719', airline='Vistara', origin='Delhi', destination='Kolkata', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 20, 10), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,952 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='778', airline='Vistara', origin='Port Blair', destination='Kolkata', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 13, 55), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 16, 15), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,953 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='733', airline='Vistara', origin='Chennai', destination='Kolkata', dayOfWeek='Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 45), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='28-10-2018')
# 2025-04-19 13:23:12,954 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='733', airline='Vistara', origin='Chennai', destination='Kolkata', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 7, 45), scheduledArrivalTime=None, validFrom='29-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,955 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='731', airline='Vistara', origin='Chennai', destination='Kolkata', dayOfWeek='Monday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 14, 25), scheduledArrivalTime=None, validFrom='30-10-2018', validTo='26-03-2019')
# 2025-04-19 13:23:12,957 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='731', airline='Vistara', origin='Chennai', destination='Kolkata', dayOfWeek='Sunday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 17, 30), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 19, 50), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,958 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='799', airline='Vistara', origin='Delhi', destination='Srinagar', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 10, 25), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,959 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='612', airline='Vistara', origin='Jammu', destination='Srinagar', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 14, 25), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 15, 25), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,960 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='212', airline='TruJet', origin='Aurangabad', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 19, 15), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 20, 45), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,961 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='212', airline='TruJet', origin='Aurangabad', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 18, 30), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 20, 15), validFrom='31-03-2019', validTo='26-10-2019')
# 2025-04-19 13:23:12,963 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='192', airline='TruJet', origin='Visakhapatnam', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 6, 45), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 11, 40), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,964 - INFO - Found null scheduledArrivalTime in row: Row(flightNumber='194', airline='TruJet', origin='Visakhapatnam', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 21, 15), scheduledArrivalTime=None, validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,965 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='142', airline='TruJet', origin='Rajahmundry', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 10, 30), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 11, 40), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,966 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='144', airline='TruJet', origin='Rajahmundry', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 18, 25), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 19, 35), validFrom='28-10-2018', validTo='30-03-2019')
# 2025-04-19 13:23:12,969 - INFO - scheduledArrivalTime is not null in row: Row(flightNumber='132', airline='TruJet', origin='Vijayawada', destination='Hyderabad', dayOfWeek='Sunday,Monday,Tuesday,Wednesday,Thursday,Friday,Saturday', scheduledDepartureTime=datetime.datetime(2025, 4, 19, 8, 0), scheduledArrivalTime=datetime.datetime(2025, 4, 19, 8, 50), validFrom='28-10-2018', validTo='30-03-2019')
